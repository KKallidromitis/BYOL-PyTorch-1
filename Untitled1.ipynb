# %%
import torch

# %%
src = '/home/kkallidromitis/weights/10_13_18-09_resnet50_300.pth.tar'

# %%
obj = torch.load(src,map_location='cpu')

# %%
obj
# Out:
# {'config': {'amp': {'opt_level': 'O0', 'sync_bn': True},
#   'checkpoint': {'ckpt_path': '/projects/d001/gce50852/ssl/kos/data/ckpt/detconb/{}/{}_{}_{}.pth.tar',
#    'resume_path': None,
#    'save_epoch': 50,
#    'time_stamp': None},
#   'clustering': {'add_views': True,
#    'batch_size': 0,
#    'gather': False,
#    'no_slic': False,
#    'superpixel': 'slic',
#    'per_image': False,
#    'scheduler': {'epochs': [0, 300], 'type': 'linear', 'values': [4, 128]},
#    'use_pca': 0,
#    'weight_color': 0.0,
#    'weight_spatial': 0.0},
#   'data': {'data_workers': 8,
#    'dual_views': True,
#    'image_dir': '/projects/d001/gce50852/ssl/kos/data/imagenet/',
#    'mask_type': '',
#    'n_kmeans': 9999,
#    'num_examples': 1281167,
#    'over_lap_mask': False,
#    'overlap_indicator': True,
#    'resize_size': 224,
#    'slic_segments': 100,
#    'subset': 'imagenet100',
#    'train_batch_size': 32,
#    'val_batch_size': 32,
#    'weight': False},
#   'distributed': True,
# ...
